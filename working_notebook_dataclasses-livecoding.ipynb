# %% [markdown]
# ## Classes, Data Classes and Abstractions

# %% [markdown]
# ### Recap Data Problem

# %% [markdown]
# $\rightarrow$ _Adapted from_ : [**Software Carpentries: Programming with Python**]()
#
# ## Arthritis Inflammation
# We are studying **inflammation in patients** who have been given a new treatment for arthritis.
#
# There are `60` patients, who had their inflammation levels recorded for `40` days.
# We want to analyze these recordings to study the effect of the new arthritis treatment.
#
# To see how the treatment is affecting the patients in general, we would like to:
#
# 1. Process the file to extract data for each patient;
# 2. Calculate some statistics on each patient;
#     - e.g. average inflammation over the `40` days (or `min`, `max` .. and so on)
#     - e.g average statistics per week (we will assume `40` days account for `5` weeks)
#     - `...` (open to ideas)
# 3. Calculate some statistics on the dataset.
#     - e.g. min and max inflammation registered overall in the clinical study;
#     - e.g. the average inflammation per day across all patients.
#     - `...` (open to ideas)
#
#
# ![3-step flowchart shows inflammation data records for patients moving to the Analysis step
# where a heat map of provided data is generated moving to the Conclusion step that asks the
# question, How does the medication affect patients?](
# https://raw.githubusercontent.com/swcarpentry/python-novice-inflammation/gh-pages/fig/lesson-overview.svg "Lesson Overview")
#
#
# ### Data Format
#
# The data sets are stored in
# [comma-separated values] (CSV) format:
#
# - each row holds information for a single patient,
# - columns represent successive days.
#
# The first three rows of our first file look like this:
# ~~~
# 0,0,1,3,1,2,4,7,8,3,3,3,10,5,7,4,7,7,12,18,6,13,11,11,7,7,4,6,8,8,4,4,5,7,3,4,2,3,0,0
# 0,1,2,1,2,1,3,2,2,6,10,11,5,9,4,4,7,16,8,6,18,4,12,5,12,7,11,5,11,3,3,5,4,4,5,5,1,1,0,1
# 0,1,1,3,3,2,6,2,5,9,5,7,4,5,4,15,5,11,9,10,19,14,12,17,7,12,11,7,4,2,10,5,4,2,2,3,2,2,1,1
# ~~~
#
# Each number represents the number of inflammation bouts that a particular patient experienced on a
# given day.
#
# For example, value "6" at row 3 column 7 of the data set above means that the third
# patient was experiencing inflammation six times on the seventh day of the clinical study.
#
# Our **task** is to gather as much information as possible from the dataset, and to report back to colleagues to foster future discussions.

# %% [markdown]
# ---

# %% [markdown]
# Dealing with more _realistic cases_ ❌

# %%
import pandas as pd

# %% [markdown]
# Read data from `data/inflammation-04.csv`

# %%
import os
from pathlib import Path 

BASE_FOLDER  = Path(os.path.abspath(os.path.curdir))

DATA_FOLDER = BASE_FOLDER / "data"

DATASET_FILE = DATA_FOLDER / "inflammation-04.csv"

# %%
print(DATASET_FILE)
# Out:
# /Users/valerio/Research/UoB/lectures/fbk-academy/2021/python-data-science/data/inflammation-04.csv

# %%
df = pd.read_csv(DATASET_FILE, header=0, index_col=0)

# %%
df.head()
# Out:
#            Day1  Day2  Day3  Day4  Day5  Day6  Day7  Day8  Day9  Day10  ...  \
# PatientID                                                               ...
# 669f          0     0     1     3     1     2     4     7     8      3  ...
# 2edf          0     1     2     1     2     1     3     2     2      6  ...
# 0355          0     1     1     3     3     2     6     2     5      9  ...
# 5968          0     0     2     0     4     2     2     1     6      7  ...
# c760          0     1     1     3     3     1     3     5     2      4  ...
#
#            Day34  Day35  Day36  Day37  Day38  Day39  Day40  Sex  Age  Group
# PatientID
# 669f           7      3      4      2      3      0      0    F   76     G3
# 2edf           4      5      5      1      1      0      1    F   42     G3
# 0355           2      2      3      2      2      1      1    F   59     G3
# 5968           3      3      4      2      3      2      1    M   25     G1
# c760           2      2      4      2      0      1      1    M   60     G2
#
# [5 rows x 43 columns]

# %%
df.loc["669f"]
# Out:
# Day1      0
# Day2      0
# Day3      1
# Day4      3
# Day5      1
# Day6      2
# Day7      4
# Day8      7
# Day9      8
# Day10     3
# Day11     3
# Day12     3
# Day13    10
# Day14     5
# Day15     7
# Day16     4
# Day17     7
# Day18     7
# Day19    12
# Day20    18
# Day21     6
# Day22    13
# Day23    11
# Day24    11
# Day25     7
# Day26     7
# Day27     4
# Day28     6
# Day29     8
# Day30     8
# Day31     4
# Day32     4
# Day33     5
# Day34     7
# Day35     3
# Day36     4
# Day37     2
# Day38     3
# Day39     0
# Day40     0
# Sex       F
# Age      76
# Group    G3
# Name: 669f, dtype: object

# %% [markdown]
# ```python
# from typing import List, Dict, Tuple
# from numpy.typing import ArrayLike
#
# Dataset = List[int] ==> ArrayLike[int]
# Dataset = Dict[str, List[int]] ==> Dict[str, Tuple[int]] ==> pd.DataFrame
# ```

# %% [markdown]
# ```python
# from typing import Sequence, Any
#
# Dataset = Sequence[Patient]
# Patient = Dict[str, Any]
# ```

# %%
from typing import Sequence

Dataset = Sequence[?]

# %% [markdown]
# ```python
# Patient = {
#     "patiendID": str
#     "sex": str
#     "age" : int
#     "group": str
#     "inflammation_data": ArrayLike[int]
# }
# ```

# %% [markdown]
# **SOLUTION1:** `Patient as a Tuple`
#
# ```python
# Dataset = Sequence[Patient]
# Patient = Tuple[Any]
#
# def read_inflammation_04(filepath: Path) -> Dataset:
#     dataset = list()
#     with open(filepath) as datafile:
#         for line in datafile:
#             patient_info = line.split(",")  # ["669f", "0", "1", ..., "F", "76", "G0"]
#             patient = tuple(patient_info)
#             dataset.append(patient)
#     return dataset
#
# ```
#
# **SOLUTION 1.5**: `Patient as a specialised TUPLE`
#
# ```python
#
# Patient = Tuple[str, str, str, int, Sequence[int]]
#
# def read_inflammation_04(filepath: Path) -> Dataset:
#     dataset = list()
#     with open(filepath) as datafile:
#         for line in datafile:
#             patient_info = line.split(",")  # ["669f", "0", "1", ..., "F", "76", "G0"]
#             patient_data = [patient_info[0], patient_info[-3],
#                             patient_info[-1], patient_info[-2],
#                             np.asarray(patient_info[1:-3]).astype(int)]
#             patient = tuple(patient_data)
#             dataset.append(patient)
#     return dataset
#
# ```

# %%
from typing import Sequence, Tuple, Union
from numpy.typing import ArrayLike

Patient = Tuple[str, str, str, int, Sequence[int]]
Dataset = Sequence[Patient]

# %%
def read_inflammation_04(filepath: Path) -> Dataset:
    dataset = list()
    with open(filepath) as datafile:
        for i, line in enumerate(datafile):
            if i == 0:
                continue
            line = line.strip()
            patient_info = line.split(",")  # ["669f", "0", "1", ..., "F", "76", "G0"]
            patient_data = [patient_info[0], patient_info[-3], 
                            patient_info[-1], patient_info[-2], 
                            np.asarray(patient_info[1:-3]).astype(int)]
            patient = tuple(patient_data)
            dataset.append(patient)
    return dataset

# %%
import numpy as np

# %%
read_inflammation_04(DATASET_FILE)
# Out:
# [('669f',
#   'F',
#   'G3',
#   '76',
#   array([ 0,  0,  1,  3,  1,  2,  4,  7,  8,  3,  3,  3, 10,  5,  7,  4,  7,
#           7, 12, 18,  6, 13, 11, 11,  7,  7,  4,  6,  8,  8,  4,  4,  5,  7,
#           3,  4,  2,  3,  0,  0])),
#  ('2edf',
#   'F',
#   'G3',
#   '42',
#   array([ 0,  1,  2,  1,  2,  1,  3,  2,  2,  6, 10, 11,  5,  9,  4,  4,  7,
#          16,  8,  6, 18,  4, 12,  5, 12,  7, 11,  5, 11,  3,  3,  5,  4,  4,
#           5,  5,  1,  1,  0,  1])),
#  ('0355',
#   'F',
#   'G3',
#   '59',
#   array([ 0,  1,  1,  3,  3,  2,  6,  2,  5,  9,  5,  7,  4,  5,  4, 15,  5,
#          11,  9, 10, 19, 14, 12, 17,  7, 12, 11,  7,  4,  2, 10,  5,  4,  2,
#           2,  3,  2,  2,  1,  1])),
#  ('5968',
#   'M',
#   'G1',
#   '25',
#   array([ 0,  0,  2,  0,  4,  2,  2,  1,  6,  7, 10,  7,  9, 13,  8,  8, 15,
#          10, 10,  7, 17,  4,  4,  7,  6, 15,  6,  4,  9, 11,  3,  5,  6,  3,
#           3,  4,  2,  3,  2,  1])),
#  ('c760',
#   'M',
#   'G2',
#   '60',
#   array([ 0,  1,  1,  3,  3,  1,  3,  5,  2,  4,  4,  7,  6,  5,  3, 10,  8,
#          10,  6, 17,  9, 14,  9,  7, 13,  9, 12,  6,  7,  7,  9,  6,  3,  2,
#           2,  4,  2,  0,  1,  1])),
#  ('6b51',
#   'F',
#   'G3',
#   '65',
#   array([ 0,  0,  1,  2,  2,  4,  2,  1,  6,  4,  7,  6,  6,  9,  9, 15,  4,
#          16, 18, 12, 12,  5, 18,  9,  5,  3, 10,  3, 12,  7,  8,  4,  7,  3,
#           5,  4,  4,  3,  2,  1])),
#  ('dbaf',
#   'M',
#   'G3',
#   '38',
#   array([ 0,  0,  2,  2,  4,  2,  2,  5,  5,  8,  6,  5, 11,  9,  4, 13,  5,
#          12, 10,  6,  9, 17, 15,  8,  9,  3, 13,  7,  8,  2,  8,  8,  4,  2,
#           3,  5,  4,  1,  1,  1])),
#  ('b3b7',
#   'M',
#   'G1',
#   '39',
#   array([ 0,  0,  1,  2,  3,  1,  2,  3,  5,  3,  7,  8,  8,  5, 10,  9, 15,
#          11, 18, 19, 20,  8,  5, 13, 15, 10,  6, 10,  6,  7,  4,  9,  3,  5,
#           2,  5,  3,  2,  2,  1])),
#  ('3995',
#   'F',
#   'G1',
#   '33',
#   array([ 0,  0,  0,  3,  1,  5,  6,  5,  5,  8,  2,  4, 11, 12, 10, 11,  9,
#          10, 17, 11,  6, 16, 12,  6,  8, 14,  6, 13, 10, 11,  4,  6,  4,  7,
#           6,  3,  2,  1,  0,  0])),
#  ('d6ff',
#   'F',
#   'G3',
#   '26',
#   array([ 0,  1,  1,  2,  1,  3,  5,  3,  5,  8,  6,  8, 12,  5, 13,  6, 13,
#           8, 16,  8, 18, 15, 16, 14, 12,  7,  3,  8,  9, 11,  2,  5,  4,  5,
#           1,  4,  1,  2,  0,  0])),
#  ('2d58',
#   'M',
#   'G3',
#   '66',
#   array([ 0,  1,  0,  0,  4,  3,  3,  5,  5,  4,  5,  8,  7, 10, 13,  3,  7,
#          13, 15, 18,  8, 15, 15, 16, 11, 14, 12,  4, 10, 10,  4,  3,  4,  5,
#           5,  3,  3,  2,  2,  1])),
#  ('a1d4',
#   'F',
#   'G3',
#   '60',
#   array([ 0,  1,  0,  0,  3,  4,  2,  7,  8,  5,  2,  8, 11,  5,  5,  8, 14,
#          11,  6, 11,  9, 16, 18,  6, 12,  5,  4,  3,  5,  7,  8,  3,  5,  4,
#           5,  5,  4,  0,  1,  1])),
#  ('71e9',
#   'M',
#   'G3',
#   '36',
#   array([ 0,  0,  2,  1,  4,  3,  6,  4,  6,  7,  9,  9,  3, 11,  6, 12,  4,
#          17, 13, 15, 13, 12,  8,  7,  4,  7, 12,  9,  5,  6,  5,  4,  7,  3,
#           5,  4,  2,  3,  0,  1])),
#  ('65c1',
#   'M',
#   'G3',
#   '59',
#   array([ 0,  0,  0,  0,  1,  3,  1,  6,  6,  5,  5,  6,  3,  6, 13,  3, 10,
#          13,  9, 16, 15,  9, 11,  4,  6,  4, 11, 11, 12,  3,  5,  8,  7,  4,
#           6,  4,  1,  3,  0,  0])),
#  ('1edd',
#   'F',
#   'G2',
#   '42',
#   array([ 0,  1,  2,  1,  1,  1,  4,  1,  5,  2,  3,  3, 10,  7, 13,  5,  7,
#          17,  6,  9, 12, 13, 10,  4, 12,  4,  6,  7,  6, 10,  8,  2,  5,  1,
#           3,  4,  2,  0,  2,  0])),
#  ('277b',
#   'F',
#   'G2',
#   '40',
#   array([ 0,  1,  1,  0,  1,  2,  4,  3,  6,  4,  7,  5,  5,  7,  5, 10,  7,
#           8, 18, 17,  9,  8, 12, 11, 11, 11, 14,  6, 11,  2, 10,  9,  5,  6,
#           5,  3,  4,  2,  2,  0])),
#  ('fe0e',
#   'M',
#   'G1',
#   '43',
#   array([ 0,  0,  0,  0,  2,  3,  6,  5,  7,  4,  3,  2, 10,  7,  9, 11, 12,
#           5, 12,  9, 13, 19, 14, 17,  5, 13,  8, 11,  5, 10,  9,  8,  7,  5,
#           3,  1,  4,  0,  2,  1])),
#  ('66d3',
#   'F',
#   'G1',
#   '44',
#   array([ 0,  0,  0,  1,  2,  1,  4,  3,  6,  7,  4,  2, 12,  6, 12,  4, 14,
#           7,  8, 14, 13, 19,  6,  9, 12,  6,  4, 13,  6,  7,  2,  3,  6,  5,
#           4,  2,  3,  0,  1,  0])),
#  ('3ff3',
#   'F',
#   'G2',
#   '55',
#   array([ 0,  0,  2,  1,  2,  5,  4,  2,  7,  8,  4,  7, 11,  9,  8, 11, 15,
#          17, 11, 12,  7, 12,  7,  6,  7,  4, 13,  5,  7,  6,  6,  9,  2,  1,
#           1,  2,  2,  0,  1,  0])),
#  ('4102',
#   'M',
#   'G3',
#   '25',
#   array([ 0,  1,  2,  0,  1,  4,  3,  2,  2,  7,  3,  3, 12, 13, 11, 13,  6,
#           5,  9, 16,  9, 19, 16, 11,  8,  9, 14, 12, 11,  9,  6,  6,  6,  1,
#           1,  2,  4,  3,  1,  1])),
#  ('12c9',
#   'M',
#   'G3',
#   '59',
#   array([ 0,  1,  1,  3,  1,  4,  4,  1,  8,  2,  2,  3, 12, 12, 10, 15, 13,
#           6,  5,  5, 18, 19,  9,  6, 11, 12,  7,  6,  3,  6,  3,  2,  4,  3,
#           1,  5,  4,  2,  2,  0])),
#  ('5b04',
#   'F',
#   'G1',
#   '79',
#   array([ 0,  0,  2,  3,  2,  3,  2,  6,  3,  8,  7,  4,  6,  6,  9,  5, 12,
#          12,  8,  5, 12, 10, 16,  7, 14, 12,  5,  4,  6,  9,  8,  5,  6,  6,
#           1,  4,  3,  0,  2,  0])),
#  ('1fef',
#   'F',
#   'G1',
#   '64',
#   array([ 0,  0,  0,  3,  4,  5,  1,  7,  7,  8,  2,  5, 12,  4, 10, 14,  5,
#           5, 17, 13, 16, 15, 13,  6, 12,  9, 10,  3,  3,  7,  4,  4,  8,  2,
#           6,  5,  1,  0,  1,  0])),
#  ('01c0',
#   'F',
#   'G2',
#   '79',
#   array([ 0,  1,  1,  1,  1,  3,  3,  2,  6,  3,  9,  7,  8,  8,  4, 13,  7,
#          14, 11, 15, 14, 13,  5, 13,  7, 14,  9, 10,  5, 11,  5,  3,  5,  1,
#           1,  4,  4,  1,  2,  0])),
#  ('57b5',
#   'F',
#   'G2',
#   '35',
#   array([ 0,  1,  1,  1,  2,  3,  5,  3,  6,  3,  7, 10,  3,  8, 12,  4, 12,
#           9, 15,  5, 17, 16,  5, 10, 10, 15,  7,  5,  3, 11,  5,  5,  6,  1,
#           1,  1,  1,  0,  2,  1])),
#  ('226c',
#   'M',
#   'G1',
#   '49',
#   array([ 0,  0,  2,  1,  3,  3,  2,  7,  4,  4,  3,  8, 12,  9, 12,  9,  5,
#          16,  8, 17,  7, 11, 14,  7, 13, 11,  7, 12, 12,  7,  8,  5,  7,  2,
#           2,  4,  1,  1,  1,  0])),
#  ('c653',
#   'F',
#   'G2',
#   '58',
#   array([ 0,  0,  1,  2,  4,  2,  2,  3,  5,  7, 10,  5,  5, 12,  3, 13,  4,
#          13,  7, 15,  9, 12, 18, 14, 16, 12,  3, 11,  3,  2,  7,  4,  8,  2,
#           2,  1,  3,  0,  1,  1])),
#  ('94fd',
#   'M',
#   'G1',
#   '80',
#   array([ 0,  0,  1,  1,  1,  5,  1,  5,  2,  2,  4, 10,  4,  8, 14,  6, 15,
#           6, 12, 15, 15, 13,  7, 17,  4,  5, 11,  4,  8,  7,  9,  4,  5,  3,
#           2,  5,  4,  3,  2,  1])),
#  ('ebf2',
#   'F',
#   'G3',
#   '71',
#   array([ 0,  0,  2,  2,  3,  4,  6,  3,  7,  6,  4,  5,  8,  4,  7,  7,  6,
#          11, 12, 19, 20, 18,  9,  5,  4,  7, 14,  8,  4,  3,  7,  7,  8,  3,
#           5,  4,  1,  3,  1,  0])),
#  ('fc73',
#   'F',
#   'G3',
#   '33',
#   array([ 0,  0,  0,  1,  4,  4,  6,  3,  8,  6,  4, 10, 12,  3,  3,  6,  8,
#           7, 17, 16, 14, 15, 17,  4, 14, 13,  4,  4, 12, 11,  6,  9,  5,  5,
#           2,  5,  2,  1,  0,  1])),
#  ('d4a0',
#   'M',
#   'G3',
#   '63',
#   array([ 0,  1,  1,  0,  3,  2,  4,  6,  8,  6,  2,  3, 11,  3, 14, 14, 12,
#           8,  8, 16, 13,  7,  6,  9, 15,  7,  6,  4, 10,  8, 10,  4,  2,  6,
#           5,  5,  2,  3,  2,  1])),
#  ('a9f2',
#   'M',
#   'G3',
#   '27',
#   array([ 0,  0,  2,  3,  3,  4,  5,  3,  6,  7, 10,  5, 10, 13, 14,  3,  8,
#          10,  9,  9, 19, 15, 15,  6,  8,  8, 11,  5,  5,  7,  3,  6,  6,  4,
#           5,  2,  2,  3,  0,  0])),
#  ('dc22',
#   'M',
#   'G3',
#   '67',
#   array([ 0,  1,  2,  2,  2,  3,  6,  6,  6,  7,  6,  3, 11, 12, 13, 15, 15,
#          10, 14, 11, 11,  8,  6, 12, 10,  5, 12,  7,  7, 11,  5,  8,  5,  2,
#           5,  5,  2,  0,  2,  1])),
#  ('a6e7',
#   'M',
#   'G3',
#   '58',
#   array([ 0,  0,  2,  1,  3,  5,  6,  7,  5,  8,  9,  3, 12, 10, 12,  4, 12,
#           9, 13, 10, 10,  6, 10, 11,  4, 15, 13,  7,  3,  4,  2,  9,  7,  2,
#           4,  2,  1,  2,  1,  1])),
#  ('3fb2',
#   'M',
#   'G1',
#   '79',
#   array([ 0,  0,  1,  2,  4,  1,  5,  5,  2,  3,  4,  8,  8, 12,  5, 15,  9,
#          17,  7, 19, 14, 18, 12, 17, 14,  4, 13, 13,  8, 11,  5,  6,  6,  2,
#           3,  5,  2,  1,  1,  1])),
#  ('11cc',
#   'M',
#   'G3',
#   '25',
#   array([ 0,  0,  0,  3,  1,  3,  6,  4,  3,  4,  8,  3,  4,  8,  3, 11,  5,
#           7, 10,  5, 15,  9, 16, 17, 16,  3,  8,  9,  8,  3,  3,  9,  5,  1,
#           6,  5,  4,  2,  2,  0])),
#  ('c9f5',
#   'M',
#   'G1',
#   '66',
#   array([ 0,  1,  2,  2,  2,  5,  5,  1,  4,  6,  3,  6,  5,  9,  6,  7,  4,
#           7, 16,  7, 16, 13,  9, 16, 12,  6,  7,  9, 10,  3,  6,  4,  5,  4,
#           6,  3,  4,  3,  2,  1])),
#  ('a73f',
#   'F',
#   'G1',
#   '77',
#   array([ 0,  1,  1,  2,  3,  1,  5,  1,  2,  2,  5,  7,  6,  6,  5, 10,  6,
#           7, 17, 13, 15, 16, 17, 14,  4,  4, 10, 10, 10, 11,  9,  9,  5,  4,
#           4,  2,  1,  0,  1,  0])),
#  ('dab2',
#   'F',
#   'G2',
#   '41',
#   array([ 0,  1,  0,  3,  2,  4,  1,  1,  5,  9, 10,  7, 12, 10,  9, 15, 12,
#          13, 13,  6, 19,  9, 10,  6, 13,  5, 13,  6,  7,  2,  5,  5,  2,  1,
#           1,  1,  1,  3,  0,  1])),
#  ('65a1',
#   'M',
#   'G1',
#   '57',
#   array([ 0,  1,  1,  3,  1,  1,  5,  5,  3,  7,  2,  2,  3, 12,  4,  6,  8,
#          15, 16, 16, 15,  4, 14,  5, 13, 10,  7, 10,  6,  3,  2,  3,  6,  3,
#           3,  5,  4,  3,  2,  1])),
#  ('8bcb',
#   'M',
#   'G2',
#   '24',
#   array([ 0,  0,  0,  2,  2,  1,  3,  4,  5,  5,  6,  5,  5, 12, 13,  5,  7,
#           5, 11, 15, 18,  7,  9, 10, 14, 12, 11,  9, 10,  3,  2,  9,  6,  2,
#           2,  5,  3,  0,  0,  1])),
#  ('4004',
#   'M',
#   'G3',
#   '34',
#   array([ 0,  0,  1,  3,  3,  1,  2,  1,  8,  9,  2,  8, 10,  3,  8,  6, 10,
#          13, 11, 17, 19,  6,  4, 11,  6, 12,  7,  5,  5,  4,  4,  8,  2,  6,
#           6,  4,  2,  2,  0,  0])),
#  ('c2af',
#   'F',
#   'G3',
#   '65',
#   array([ 0,  1,  1,  3,  4,  5,  2,  1,  3,  7,  9,  6, 10,  5,  8, 15, 11,
#          12, 15,  6, 12, 16,  6,  4, 14,  3, 12,  9,  6, 11,  5,  8,  5,  5,
#           6,  1,  2,  1,  2,  0])),
#  ('8037',
#   'M',
#   'G2',
#   '53',
#   array([ 0,  0,  1,  3,  1,  4,  3,  6,  7,  8,  5,  7, 11,  3,  6, 11,  6,
#          10,  6, 19, 18, 14,  6, 10,  7,  9,  8,  5,  8,  3, 10,  2,  5,  1,
#           5,  4,  2,  1,  0,  1])),
#  ('cb49',
#   'F',
#   'G2',
#   '63',
#   array([ 0,  1,  1,  3,  3,  4,  4,  6,  3,  4,  9,  9,  7,  6,  8, 15, 12,
#          15,  6, 11,  6, 18,  5, 14, 15, 12,  9,  8,  3,  6, 10,  6,  8,  7,
#           2,  5,  4,  3,  1,  1])),
#  ('2b4b',
#   'F',
#   'G3',
#   '60',
#   array([ 0,  1,  2,  2,  4,  3,  1,  4,  8,  9,  5, 10, 10,  3,  4,  6,  7,
#          11, 16,  6, 14,  9, 11, 10, 10,  7, 10,  8,  8,  4,  5,  8,  4,  4,
#           5,  2,  4,  1,  1,  0])),
#  ('80a8',
#   'M',
#   'G2',
#   '24',
#   array([ 0,  0,  2,  3,  4,  5,  4,  6,  2,  9,  7,  4,  9, 10,  8, 11, 16,
#          12, 15, 17, 19, 10, 18, 13, 15, 11,  8,  4,  7, 11,  6,  7,  6,  5,
#           1,  3,  1,  0,  0,  0])),
#  ('ac50',
#   'M',
#   'G1',
#   '68',
#   array([ 0,  1,  1,  3,  1,  4,  6,  2,  8,  2, 10,  3, 11,  9, 13, 15,  5,
#          15,  6, 10, 10,  5, 14, 15, 12,  7,  4,  5, 11,  4,  6,  9,  5,  6,
#           1,  1,  2,  1,  2,  1])),
#  ('57ef',
#   'F',
#   'G1',
#   '75',
#   array([ 0,  0,  1,  3,  2,  5,  1,  2,  7,  6,  6,  3, 12,  9,  4, 14,  4,
#           6, 12,  9, 12,  7, 11,  7, 16,  8, 13,  6,  7,  6, 10,  7,  6,  3,
#           1,  5,  4,  3,  0,  0])),
#  ('cc45',
#   'F',
#   'G2',
#   '37',
#   array([ 0,  0,  1,  2,  3,  4,  5,  7,  5,  4, 10,  5, 12, 12,  5,  4,  7,
#           9, 18, 16, 16, 10, 15, 15, 10,  4,  3,  7,  5,  9,  4,  6,  2,  4,
#           1,  4,  2,  2,  2,  1])),
#  ('9184',
#   'F',
#   'G1',
#   '37',
#   array([ 0,  1,  2,  1,  1,  3,  5,  3,  6,  3, 10, 10, 11, 10, 13, 10, 13,
#           6,  6, 14,  5,  4,  5,  5,  9,  4, 12,  7,  7,  4,  7,  9,  3,  3,
#           6,  3,  4,  1,  2,  0])),
#  ('84be',
#   'M',
#   'G3',
#   '27',
#   array([ 0,  1,  2,  2,  3,  5,  2,  4,  5,  6,  8,  3,  5,  4,  3, 15, 15,
#          12, 16,  7, 20, 15, 12,  8,  9,  6, 12,  5,  8,  3,  8,  5,  4,  1,
#           3,  2,  1,  3,  1,  0])),
#  ('0af0',
#   'F',
#   'G1',
#   '68',
#   array([ 0,  0,  0,  2,  4,  4,  5,  3,  3,  3, 10,  4,  4,  4, 14, 11, 15,
#          13, 10, 14, 11, 17,  9, 11, 11,  7, 10, 12, 10, 10, 10,  8,  7,  5,
#           2,  2,  4,  1,  2,  1])),
#  ('bf77',
#   'F',
#   'G3',
#   '52',
#   array([ 0,  0,  2,  1,  1,  4,  4,  7,  2,  9,  4, 10, 12,  7,  6,  6, 11,
#          12,  9, 15, 15,  6,  6, 13,  5, 12,  9,  6,  4,  7,  7,  6,  5,  4,
#           1,  4,  2,  2,  2,  1])),
#  ('c56c',
#   'M',
#   'G1',
#   '48',
#   array([ 0,  1,  2,  1,  1,  4,  5,  4,  4,  5,  9,  7, 10,  3, 13, 13,  8,
#           9, 17, 16, 16, 15, 12, 13,  5, 12, 10,  9, 11,  9,  4,  5,  5,  2,
#           2,  5,  1,  0,  0,  1])),
#  ('7d0c',
#   'F',
#   'G1',
#   '40',
#   array([ 0,  0,  1,  3,  2,  3,  6,  4,  5,  7,  2,  4, 11, 11,  3,  8,  8,
#          16,  5, 13, 16,  5,  8,  8,  6,  9, 10, 10,  9,  3,  3,  5,  3,  5,
#           4,  5,  3,  3,  0,  1])),
#  ('c736',
#   'M',
#   'G1',
#   '30',
#   array([ 0,  1,  1,  2,  2,  5,  1,  7,  4,  2,  5,  5,  4,  6,  6,  4, 16,
#          11, 14, 16, 14, 14,  8, 17,  4, 14, 13,  7,  6,  3,  7,  7,  5,  6,
#           3,  4,  2,  2,  1,  1])),
#  ('c5c8',
#   'M',
#   'G3',
#   '77',
#   array([ 0,  1,  1,  1,  4,  1,  6,  4,  6,  3,  6,  5,  6,  4, 14, 13, 13,
#           9, 12, 19,  9, 10, 15, 10,  9, 10, 10,  7,  5,  6,  8,  6,  6,  4,
#           3,  5,  2,  1,  1,  1])),
#  ('050a',
#   'M',
#   'G1',
#   '49',
#   array([ 0,  0,  0,  1,  4,  5,  6,  3,  8,  7,  9, 10,  8,  6,  5, 12, 15,
#           5, 10,  5,  8, 13, 18, 17, 14,  9, 13,  4, 10, 11, 10,  8,  8,  6,
#           5,  5,  2,  0,  2,  0])),
#  ('a085',
#   'F',
#   'G3',
#   '29',
#   array([ 0,  0,  1,  0,  3,  2,  5,  4,  8,  2,  9,  3,  3, 10, 12,  9, 14,
#          11, 13,  8,  6, 18, 11,  9, 13, 11,  8,  5,  5,  2,  8,  5,  3,  5,
#           4,  1,  3,  1,  1,  0]))]

# %% [markdown]
# **SOLUTION 2:** Patient as a `namedtuple`
#
# ```python
#
# # TYPE HINT
# Patient = PatientTuple
# Dataset = Sequence[Patient]
#
# ```

# %%
from collections import namedtuple

PatientTuple = namedtuple("PatientTuple", ["pid", "sex", "group", "age", "inflammation_data"])

# %%
def read_inflammation_04(filepath: Path) -> Dataset:
    dataset = list()
    with open(filepath) as datafile:
        for i, line in enumerate(datafile):
            if i == 0:
                continue
            line = line.strip()
            patient_info = line.split(",")  # ["669f", "0", "1", ..., "F", "76", "G0"]
            patient = PatientTuple(pid=patient_info[0], 
                                   sex=patient_info[-3], group=patient_info[-1], 
                                   age=int(patient_info[-2]), 
                                   inflammation_data=np.asarray(patient_info[1:-3]).astype(int)
                                  )
            dataset.append(patient)
    return dataset

# %%
dataset = read_inflammation_04(DATASET_FILE)

# %%
type(dataset)
# Out:
# list

# %%
type(dataset[0])
# Out:
# __main__.PatientTuple

# %%
patient = dataset[1]

print(f"{patient.pid}, Age: {patient.age}, Group: {patient.group}")
# Out:
# 2edf, Age: 42, Group: G3

# %%
def g3_filter_function(patient: PatientTuple) -> bool:
    return patient.group == "G3"

g3_patients = filter(g3_filter_function, dataset)

# %%
type(g3_patients)
# Out:
# filter

# %%
g3_patients = list(g3_patients)

# %%
len(g3_patients)
# Out:
# 26

# %%
g3_patients
# Out:
# [PatientTuple(pid='669f', sex='F', group='G3', age=76, inflammation_data=array([ 0,  0,  1,  3,  1,  2,  4,  7,  8,  3,  3,  3, 10,  5,  7,  4,  7,
#          7, 12, 18,  6, 13, 11, 11,  7,  7,  4,  6,  8,  8,  4,  4,  5,  7,
#          3,  4,  2,  3,  0,  0])),
#  PatientTuple(pid='2edf', sex='F', group='G3', age=42, inflammation_data=array([ 0,  1,  2,  1,  2,  1,  3,  2,  2,  6, 10, 11,  5,  9,  4,  4,  7,
#         16,  8,  6, 18,  4, 12,  5, 12,  7, 11,  5, 11,  3,  3,  5,  4,  4,
#          5,  5,  1,  1,  0,  1])),
#  PatientTuple(pid='0355', sex='F', group='G3', age=59, inflammation_data=array([ 0,  1,  1,  3,  3,  2,  6,  2,  5,  9,  5,  7,  4,  5,  4, 15,  5,
#         11,  9, 10, 19, 14, 12, 17,  7, 12, 11,  7,  4,  2, 10,  5,  4,  2,
#          2,  3,  2,  2,  1,  1])),
#  PatientTuple(pid='6b51', sex='F', group='G3', age=65, inflammation_data=array([ 0,  0,  1,  2,  2,  4,  2,  1,  6,  4,  7,  6,  6,  9,  9, 15,  4,
#         16, 18, 12, 12,  5, 18,  9,  5,  3, 10,  3, 12,  7,  8,  4,  7,  3,
#          5,  4,  4,  3,  2,  1])),
#  PatientTuple(pid='dbaf', sex='M', group='G3', age=38, inflammation_data=array([ 0,  0,  2,  2,  4,  2,  2,  5,  5,  8,  6,  5, 11,  9,  4, 13,  5,
#         12, 10,  6,  9, 17, 15,  8,  9,  3, 13,  7,  8,  2,  8,  8,  4,  2,
#          3,  5,  4,  1,  1,  1])),
#  PatientTuple(pid='d6ff', sex='F', group='G3', age=26, inflammation_data=array([ 0,  1,  1,  2,  1,  3,  5,  3,  5,  8,  6,  8, 12,  5, 13,  6, 13,
#          8, 16,  8, 18, 15, 16, 14, 12,  7,  3,  8,  9, 11,  2,  5,  4,  5,
#          1,  4,  1,  2,  0,  0])),
#  PatientTuple(pid='2d58', sex='M', group='G3', age=66, inflammation_data=array([ 0,  1,  0,  0,  4,  3,  3,  5,  5,  4,  5,  8,  7, 10, 13,  3,  7,
#         13, 15, 18,  8, 15, 15, 16, 11, 14, 12,  4, 10, 10,  4,  3,  4,  5,
#          5,  3,  3,  2,  2,  1])),
#  PatientTuple(pid='a1d4', sex='F', group='G3', age=60, inflammation_data=array([ 0,  1,  0,  0,  3,  4,  2,  7,  8,  5,  2,  8, 11,  5,  5,  8, 14,
#         11,  6, 11,  9, 16, 18,  6, 12,  5,  4,  3,  5,  7,  8,  3,  5,  4,
#          5,  5,  4,  0,  1,  1])),
#  PatientTuple(pid='71e9', sex='M', group='G3', age=36, inflammation_data=array([ 0,  0,  2,  1,  4,  3,  6,  4,  6,  7,  9,  9,  3, 11,  6, 12,  4,
#         17, 13, 15, 13, 12,  8,  7,  4,  7, 12,  9,  5,  6,  5,  4,  7,  3,
#          5,  4,  2,  3,  0,  1])),
#  PatientTuple(pid='65c1', sex='M', group='G3', age=59, inflammation_data=array([ 0,  0,  0,  0,  1,  3,  1,  6,  6,  5,  5,  6,  3,  6, 13,  3, 10,
#         13,  9, 16, 15,  9, 11,  4,  6,  4, 11, 11, 12,  3,  5,  8,  7,  4,
#          6,  4,  1,  3,  0,  0])),
#  PatientTuple(pid='4102', sex='M', group='G3', age=25, inflammation_data=array([ 0,  1,  2,  0,  1,  4,  3,  2,  2,  7,  3,  3, 12, 13, 11, 13,  6,
#          5,  9, 16,  9, 19, 16, 11,  8,  9, 14, 12, 11,  9,  6,  6,  6,  1,
#          1,  2,  4,  3,  1,  1])),
#  PatientTuple(pid='12c9', sex='M', group='G3', age=59, inflammation_data=array([ 0,  1,  1,  3,  1,  4,  4,  1,  8,  2,  2,  3, 12, 12, 10, 15, 13,
#          6,  5,  5, 18, 19,  9,  6, 11, 12,  7,  6,  3,  6,  3,  2,  4,  3,
#          1,  5,  4,  2,  2,  0])),
#  PatientTuple(pid='ebf2', sex='F', group='G3', age=71, inflammation_data=array([ 0,  0,  2,  2,  3,  4,  6,  3,  7,  6,  4,  5,  8,  4,  7,  7,  6,
#         11, 12, 19, 20, 18,  9,  5,  4,  7, 14,  8,  4,  3,  7,  7,  8,  3,
#          5,  4,  1,  3,  1,  0])),
#  PatientTuple(pid='fc73', sex='F', group='G3', age=33, inflammation_data=array([ 0,  0,  0,  1,  4,  4,  6,  3,  8,  6,  4, 10, 12,  3,  3,  6,  8,
#          7, 17, 16, 14, 15, 17,  4, 14, 13,  4,  4, 12, 11,  6,  9,  5,  5,
#          2,  5,  2,  1,  0,  1])),
#  PatientTuple(pid='d4a0', sex='M', group='G3', age=63, inflammation_data=array([ 0,  1,  1,  0,  3,  2,  4,  6,  8,  6,  2,  3, 11,  3, 14, 14, 12,
#          8,  8, 16, 13,  7,  6,  9, 15,  7,  6,  4, 10,  8, 10,  4,  2,  6,
#          5,  5,  2,  3,  2,  1])),
#  PatientTuple(pid='a9f2', sex='M', group='G3', age=27, inflammation_data=array([ 0,  0,  2,  3,  3,  4,  5,  3,  6,  7, 10,  5, 10, 13, 14,  3,  8,
#         10,  9,  9, 19, 15, 15,  6,  8,  8, 11,  5,  5,  7,  3,  6,  6,  4,
#          5,  2,  2,  3,  0,  0])),
#  PatientTuple(pid='dc22', sex='M', group='G3', age=67, inflammation_data=array([ 0,  1,  2,  2,  2,  3,  6,  6,  6,  7,  6,  3, 11, 12, 13, 15, 15,
#         10, 14, 11, 11,  8,  6, 12, 10,  5, 12,  7,  7, 11,  5,  8,  5,  2,
#          5,  5,  2,  0,  2,  1])),
#  PatientTuple(pid='a6e7', sex='M', group='G3', age=58, inflammation_data=array([ 0,  0,  2,  1,  3,  5,  6,  7,  5,  8,  9,  3, 12, 10, 12,  4, 12,
#          9, 13, 10, 10,  6, 10, 11,  4, 15, 13,  7,  3,  4,  2,  9,  7,  2,
#          4,  2,  1,  2,  1,  1])),
#  PatientTuple(pid='11cc', sex='M', group='G3', age=25, inflammation_data=array([ 0,  0,  0,  3,  1,  3,  6,  4,  3,  4,  8,  3,  4,  8,  3, 11,  5,
#          7, 10,  5, 15,  9, 16, 17, 16,  3,  8,  9,  8,  3,  3,  9,  5,  1,
#          6,  5,  4,  2,  2,  0])),
#  PatientTuple(pid='4004', sex='M', group='G3', age=34, inflammation_data=array([ 0,  0,  1,  3,  3,  1,  2,  1,  8,  9,  2,  8, 10,  3,  8,  6, 10,
#         13, 11, 17, 19,  6,  4, 11,  6, 12,  7,  5,  5,  4,  4,  8,  2,  6,
#          6,  4,  2,  2,  0,  0])),
#  PatientTuple(pid='c2af', sex='F', group='G3', age=65, inflammation_data=array([ 0,  1,  1,  3,  4,  5,  2,  1,  3,  7,  9,  6, 10,  5,  8, 15, 11,
#         12, 15,  6, 12, 16,  6,  4, 14,  3, 12,  9,  6, 11,  5,  8,  5,  5,
#          6,  1,  2,  1,  2,  0])),
#  PatientTuple(pid='2b4b', sex='F', group='G3', age=60, inflammation_data=array([ 0,  1,  2,  2,  4,  3,  1,  4,  8,  9,  5, 10, 10,  3,  4,  6,  7,
#         11, 16,  6, 14,  9, 11, 10, 10,  7, 10,  8,  8,  4,  5,  8,  4,  4,
#          5,  2,  4,  1,  1,  0])),
#  PatientTuple(pid='84be', sex='M', group='G3', age=27, inflammation_data=array([ 0,  1,  2,  2,  3,  5,  2,  4,  5,  6,  8,  3,  5,  4,  3, 15, 15,
#         12, 16,  7, 20, 15, 12,  8,  9,  6, 12,  5,  8,  3,  8,  5,  4,  1,
#          3,  2,  1,  3,  1,  0])),
#  PatientTuple(pid='bf77', sex='F', group='G3', age=52, inflammation_data=array([ 0,  0,  2,  1,  1,  4,  4,  7,  2,  9,  4, 10, 12,  7,  6,  6, 11,
#         12,  9, 15, 15,  6,  6, 13,  5, 12,  9,  6,  4,  7,  7,  6,  5,  4,
#          1,  4,  2,  2,  2,  1])),
#  PatientTuple(pid='c5c8', sex='M', group='G3', age=77, inflammation_data=array([ 0,  1,  1,  1,  4,  1,  6,  4,  6,  3,  6,  5,  6,  4, 14, 13, 13,
#          9, 12, 19,  9, 10, 15, 10,  9, 10, 10,  7,  5,  6,  8,  6,  6,  4,
#          3,  5,  2,  1,  1,  1])),
#  PatientTuple(pid='a085', sex='F', group='G3', age=29, inflammation_data=array([ 0,  0,  1,  0,  3,  2,  5,  4,  8,  2,  9,  3,  3, 10, 12,  9, 14,
#         11, 13,  8,  6, 18, 11,  9, 13, 11,  8,  5,  5,  2,  8,  5,  3,  5,
#          4,  1,  3,  1,  1,  0]))]

# %% [markdown]
# ```python
#
# def read_inflammation_04(filepath: Path) -> Dataset:
#     dataset = list()
#     with open(filepath) as datafile:
#         for i, line in enumerate(datafile):
#             if i == 0:
#                 continue
#             line = line.strip()
#             patient_info = line.split(",")  # ["669f", "0", "1", ..., "F", "76", "G0"]
#             patient = ?
#             dataset.append(patient)
#     return dataset
# ```

# %% [markdown]
# Putting our helmets on (_with some testing_) ⛑

# %% [markdown]
# Now it's time to rethink about our Data (Abstractions): let's define our own **new type**!
